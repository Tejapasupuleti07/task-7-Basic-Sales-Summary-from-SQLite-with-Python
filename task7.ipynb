# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Connect to your sales_data.db file
conn = sqlite3.connect("sales_data.db")

# %%
# SQL query to calculate total quantity & revenue by product
query = """
SELECT product,
       SUM(quantity) AS total_qty,
       SUM(quantity * price) AS revenue
FROM sales
GROUP BY product
"""

# Load query result into Pandas DataFrame
df = pd.read_sql_query(query, conn)

# %%
print("=== Sales Summary ===")
print(df)
# Out:
# === Sales Summary ===
#   product  total_qty    revenue
# 0  Laptop         22  1115000.0
# 1   Phone         52  1058500.0
# 2  Tablet         13   197000.0

# %%
# Plot bar chart for revenue
df.plot(kind='bar', x='product', y='revenue', legend=False)
plt.ylabel("Revenue")
plt.title("Revenue by Product")
plt.tight_layout()
plt.savefig("sales_chart.png")  # Save chart
plt.show()

# %%
conn.close()
